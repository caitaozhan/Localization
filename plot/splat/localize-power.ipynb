# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
plt.rcParams['font.size'] = 25

# %%
filename = '{}-{}-{}.txt'

# %%
power = np.loadtxt(filename.format(5, 'ours', 'power'), delimiter=',')

# %%
power
# Out:
# array([ 0.62231259, -0.12496404,  1.28664286, -0.14087396,  1.02041125,
#         0.77941909,  0.17161115,  0.94490152,  2.46573141,  1.74875021,
#         0.17586291,  0.97362299,  2.02918713,  0.65800449, -0.20394976,
#         0.63659823,  0.75654964,  1.46787008,  1.09625282, -0.63726172,
#         0.5745642 ,  1.50079624,  1.65617159,  0.38718264, -0.26606038,
#         1.39445272,  0.24368154,  0.81922574,  0.23019886, -0.16764549,
#         0.65215745,  0.71218383,  0.98091672, -0.02449955,  1.68113446,
#        -0.28065147,  1.66524075,  0.68011089,  1.16937157,  0.21642948,
#        -0.17523281,  0.15081986,  0.6938227 ,  1.18073231,  0.73730867,
#         1.96566649,  1.07703367,  1.74737387, -0.21272049,  2.82449823,
#         0.38244924,  1.26895344,  0.79879724,  2.19048179,  0.45217852,
#        -1.69684234,  1.21316209,  0.59982738,  0.72578343,  0.49560414,
#         0.28401719,  0.94773133,  2.24789019,  0.72650396,  1.23630263,
#         0.60265535,  1.54355663, -0.25384081, -0.8103421 ,  0.7599133 ,
#         0.23859044,  1.06019903,  0.13903143,  0.2828839 ,  0.77898777,
#         0.05464219, -0.6320509 ,  1.8658866 ,  1.35998167,  0.72615643,
#         0.36193708,  0.33218949,  0.16904436,  0.77323689,  0.1580209 ,
#         0.07257747,  0.93557025, -0.64572219,  0.48959294,  0.80949313,
#         1.43348463,  1.27494055,  1.07790681,  1.10879792,  0.86808736,
#         0.3774413 ,  0.83722654,  0.58986656, -1.61846495,  0.96069021,
#         0.95565811,  0.34897985,  0.72464011, -0.06232034,  0.49275204,
#         0.16716248,  1.0449968 ,  0.00547739,  1.36398575,  0.30053899,
#         0.20557689,  0.43026662,  0.19956148,  0.84287586,  0.64080105,
#         1.93010229, -0.46761699,  0.92291545,  1.18335239,  0.29284597,
#         0.62621304,  0.26370251,  0.51316755,  0.34142689,  1.18898947,
#         0.14070466,  1.18411061,  1.77297085,  0.84797132, -0.18303133,
#         0.11882144,  1.14453878,  0.76583567,  1.54817132,  1.47659133,
#         0.57016524,  0.42408832, -0.52998688,  0.5306568 ,  0.80464438,
#        -0.99306033,  1.1616573 ,  0.55367726, -0.83758243,  0.68771763,
#         0.27128371,  1.22814776, -0.61427265,  1.07740844,  1.23266683,
#         1.1892476 ,  1.26454291,  1.1687311 ,  0.93407512,  0.74781305,
#         0.39914527,  0.33635213,  1.46348094,  0.73198456,  1.47607148,
#         0.49800898,  0.30712295,  0.34985484,  0.62669518,  0.40542143,
#        -0.1759814 ,  1.80522158, -0.06588628, -0.98922692,  0.5398195 ,
#         0.02505798,  0.73674984,  0.06714433,  0.16300986,  0.32670224,
#         0.84037747,  1.02307782,  1.63358957,  0.52334841,  0.63232038,
#        -1.33820115,  0.75110031,  0.63081153,  0.55717311, -0.26492588,
#         1.20854835,  1.1128702 ,  2.20555991,  0.92064232,  0.1793617 ,
#         2.16557316, -1.51147161,  1.69239146,  1.31383538,  0.00917993,
#         1.02116614,  1.61611273,  0.34466626,  1.65682551,  0.32468678,
#         1.41489241,  1.3597516 ,  0.43003677, -0.39587569,  0.26662229,
#         0.80473355,  1.2776116 ,  0.01810222,  1.2442886 ,  0.48113237,
#         0.55185353,  0.26672608,  1.10127249, -2.16788804,  0.87863532,
#         1.64476474,  0.2507443 ,  1.47100964,  0.44692769, -0.62710041,
#         1.29423805,  0.56085331,  1.43315271,  0.5653761 ,  0.10283418,
#         0.84737258,  0.99487216,  1.13927308,  0.50980876,  0.71177871,
#        -0.6267431 ,  0.2466989 ,  1.26165792,  0.84629638,  1.33356578,
#         0.83927639, -0.46415956])

# %%
x = power
n_bins = 30
fig, ax = plt.subplots(figsize=(12, 9))

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = ax.hist(x, bins=n_bins,density=True)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

ax.set_title('Error of Power Estimation')
ax.set_xlabel('Error (dBm)')
ax.set_ylabel('Probability Density')
fig.savefig('power.png')
