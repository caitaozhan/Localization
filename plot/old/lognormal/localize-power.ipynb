# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
plt.rcParams['font.size'] = 25

# %%
filename = '{}-{}-{}.txt'

# %%
num_intru = 1
power = np.loadtxt(filename.format(num_intru, 'ours', 'power'), delimiter=',')

x = power
n_bins = 10
fig, ax = plt.subplots(figsize=(12, 9))

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = ax.hist(x, bins=n_bins,density=True)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

ax.set_title('Error of Power Estimation ({} intruders)'.format(num_intru))
ax.set_xlabel('Error (dBm)')
ax.set_ylabel('Probability Density')
fig.savefig('power-{}.png'.format(num_intru))

# %%
num_intru = 3
power = np.loadtxt(filename.format(num_intru, 'ours', 'power'), delimiter=',')

x = power
n_bins = 20
fig, ax = plt.subplots(figsize=(12, 9))

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = ax.hist(x, bins=n_bins,density=True)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

ax.set_title('Error of Power Estimation ({} intruders)'.format(num_intru))
ax.set_xlabel('Error (dBm)')
ax.set_ylabel('Probability Density')
fig.savefig('power-{}.png'.format(num_intru))

# %%
num_intru = 5
power = np.loadtxt(filename.format(num_intru, 'ours', 'power'), delimiter=',')

x = power
n_bins = 30
fig, ax = plt.subplots(figsize=(12, 9))

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = ax.hist(x, bins=n_bins,density=True)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

ax.set_title('Error of Power Estimation ({} intruders)'.format(num_intru))
ax.set_xlabel('Error (dBm)')
ax.set_ylabel('Probability Density')
fig.savefig('power-{}.png'.format(num_intru))

# %%
num_intru = 7
power = np.loadtxt(filename.format(num_intru, 'ours', 'power'), delimiter=',')

x = power
n_bins = 30
fig, ax = plt.subplots(figsize=(12, 9))

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = ax.hist(x, bins=n_bins,density=True)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

ax.set_title('Error of Power Estimation ({} intruders)'.format(num_intru))
ax.set_xlabel('Error (dBm)')
ax.set_ylabel('Probability Density')
fig.savefig('power-{}.png'.format(num_intru))

# %%
num_intru = 10
power = np.loadtxt(filename.format(num_intru, 'ours', 'power'), delimiter=',')

x = power
n_bins = 30
fig, ax = plt.subplots(figsize=(12, 9))

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = ax.hist(x, bins=n_bins,density=True)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

ax.set_title('Error of Power Estimation ({} intruders)'.format(num_intru))
ax.set_xlabel('Error (dBm)')
ax.set_ylabel('Probability Density')
fig.savefig('power-{}.png'.format(num_intru))
