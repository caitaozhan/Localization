# %%
import random
import numpy as np
import seaborn as sns
import math
import os
import time
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import multivariate_normal
from scipy.stats import norm, entropy

# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# # IPSN data: 50 x 50 grid, 1 m x 1 m per grid cell

# %% [markdown]
# ## Varies number of sensors {50, 100, 200, 300, 400}

# %%
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
def_figsize = 60, 45

SMALL_SIZE =20
MEDIUM_SIZE=20
BIGGER_SIZE=20

plt.style.use('seaborn-paper')
sns.set(context='paper', font_scale=1)
sns.set_style("whitegrid")

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE) # fontsize of the figure title


plt.bar(range(0, 3), [0.08152770283177148, 2.26136607132348 , 5.412966333708989])
plt.xticks(range(0, 3), ['Our Algorithm', 'Clustering', 'SPLOT'])
plt.xlabel('Localization Algorithm')
plt.ylabel('Mean Localization Error (meters)')
plt.savefig('error.png')
plt.show()

plt.bar(range(0, 3), [0.0784126984126984, 0.1402777777777778, 0.1130952380952381])
plt.xticks(range(0, 3), ['Our Algorithm', 'Clustering', 'SPLOT'])
plt.xlabel('Localization Algorithm')
plt.ylabel('Miss Rate')
plt.savefig('misses.png')
plt.show()

plt.bar(range(0, 3), [0, 0.04472222222222222, 0.10753968253968253])
plt.xticks(range(0, 3), ['Our Algorithm', 'Clustering', 'SPLOT'])
plt.xlabel('Localization Algorithm')
plt.ylabel('False Alarms Rate')
plt.savefig('fa.png')
plt.show()
#X1.insert(0, 0), Y1.insert(0, 0)
#X2.insert(0, 0), Y2.insert(0, 0)
#X3.insert(0, 0), Y3.insert(0, 0)
#X4.insert(0, 0), Y4.insert(0, 0)
# Out:
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /usr/lib64/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# # SPLOT

# %% [markdown]
# R1 = 6, R2 = 7, threshold = -65
#
# error = 5.412966333708989, miss = 0.1130952380952381, false_alarm = 0.10753968253968253

# %% [markdown]
# # Ours

# %% [markdown]
# error = 0.08152770283177148, miss = 0.0784126984126984, false_alarm = 0.0

# %% [markdown]
# # Clustering

# %% [markdown]
# error = 2.26136607132348, miss = 0.1402777777777778, false_alarm = 0.04472222222222222
